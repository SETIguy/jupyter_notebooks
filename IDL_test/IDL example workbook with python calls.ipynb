# %% [markdown]
# This is how you use IDL in jupyter and how you use python in idl.

# %%
; this is an IDL window
ran=python.import('numpy.random')
a=ran.rand(100000)
print,avg(a),std(a)
b=randomu(seed,100000,/double)
print,avg(b),std(b)
# Out:
#   File "<ipython-input-1-edec81ca9053>", line 2
#     ran=python.import('numpy.random')
#                     ^
# SyntaxError: invalid syntax

# %%
# !p.background=-1 
# !p.color=1
plot,a,b,psym=3
